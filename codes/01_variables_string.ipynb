# %% [markdown]
# ## 문제 풀이
# -두 문자열 변수를 선언해서 각각 변수에 값을 넣고, + 기호를
# 이용해서 이어 붙이는 코드를 작성
# -변수 이름 first, second, result를 실행
# 결과) good morning

# %%
first = "good "

# %%
second = "morning"

# %%
result = first + " " + second

# %%
result
# Out:
# 'good  morning'
