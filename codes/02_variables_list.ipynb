# %% [markdown]
# ## 단일 리스트

# %%
first = ['1', '2', '3', '4']

# %%
first
# Out:
# ['1', '2', '3', '4']

# %%
type(first)
# Out:
# list

# %%
first[2]
# Out:
# '3'

# %%
first[3]
# Out:
# '4'

# %%
first[0]
# Out:
# '1'

# %%
second = ['morning ',
          'afteroon ',
          'night']

# %%
second
# Out:
# ['morning ', 'afteroon ', 'night']

# %%
second[0]
# Out:
# 'morning'

# %%
night = 'night'

# %%
third = ['morning',
         'afternoon',
         'night']

# %%
third
# Out:
# ['morning', 'afternoon', 'night']

# %% [markdown]
# ## 문제 풀이1

# %%
fruit1 = "apple"

# %%
fruit2 = "banana"

# %%
fruit3 = "cherry"

# %%
fruits = [fruit1, fruit2, fruit3]

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruit1
# Out:
# 'apple'

# %%
fruit2
# Out:
# 'banana'

# %%
fruit3
# Out:
# 'cherry'

# %% [markdown]
# ## 문제 풀이2

# %%
colors = ["red", "green","blue"]

# %%
colors[1]
# Out:
# 'green'

# %% [markdown]
# ## 문제 풀이3

# %%
pets = ["dog", "parrot","fush", "red", "green","blue" ]

# %%
pets[0]
# Out:
# 'dog'

# %%
pets[4]
# Out:
# 'green'
