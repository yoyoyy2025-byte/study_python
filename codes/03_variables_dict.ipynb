# %%
first = { "second" : "good" }

# %%
first
# Out:
# {'second': 'good'}

# %%
first ["second"]
# Out:
# 'good'

# %%
second = {
    "furst" : "good",
    "second" : "bad"
}

# %%
second["second"]
# Out:
# 'bad'

# %%
thied = "not bad"

# %%
second = {
    "furst" : "good",
    "second" : "bad",
    "not_key" : thied
}

# %%
second["not_key"]
# Out:
# 'not bad'

# %% [markdown]
# ## 문제 풀이 1

# %%
person = {"name" : "Alice",
"job" : "Engineer"}

# %% [markdown]
# ## 문제 풀이 2

# %%
python = {"name" : "Bob",
          "age" : "25",
          "city" : "Seoul"}

# %%
python["city"]
# Out:
# 'Seoul'

# %% [markdown]
# ## 문제 풀이 3

# %%
python = {"name" : "Charlie",
          "age" : "30",
          "city" : "Seoul"}

# %%
python
# Out:
# {'name': 'Charlie', 'age': '30', 'city': 'Seoul'}
