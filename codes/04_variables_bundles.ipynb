# %% [markdown]
# ## 함께

# %%
car_information = [

]

# %%
car_01 = {"No" : "1",
          "brand" : "Toyota",
          "model" : "Corolla",
          "Color" : "Red"
}

# %%
car_02 = {"No" : "2",
          "brand" : "Honda",
          "model" : "Civic",
          "Color" : "Black"
}

# %%
car_03 = {"No" : "3",
          "brand" : "BMW",
          "model" : "X5",
          "Color" : "White"
}

# %%
car_information_list = [
    car_01, car_02, car_03
]

# %%
car_information_duct = [{"No" : "1",
          "brand" : "Toyota",
          "model" : "Corolla",
          "Color" : "Red"},
                        {"No" : "2",
          "brand" : "Honda",
          "model" : "Civic",
          "Color" : "Black"},
                         {"No" : "3",
          "brand" : "BMW",
          "model" : "X5",
          "Color" : "White"

}]

# %%
# 딕션어리에서 특정값 확인
# car_information_duct[1]['model']
# car_information_duct[1]['brand']

# %% [markdown]
# ## 문제 풀이 1

# %%
employees = [

]

# %%
employees01 = {"No" : "1",
             "name" : "Alice"}

# %%
employees02 = {"No" : "2",
             "name" : "Bob"}

# %%
employees03 = {"No" : "3",
             "name" : "Charlie"}

# %%
employees03 = {"No" : "4",
             "name" : "Diana"}

# %%
employees = [employees01,employees02,employees03,employees04]

# %%
employees=[{"No" : "1",
             "name" : "Alice"} ,
           {"No" : "2",
             "name" : "Bob"},
           {"No" : "3",
             "name" : "Charlie"},
           {"No" : "4",
             "name" : "Diana"}
           ]

# %%
employees[0]["name"]
# Out:
# 'Alice'

# %%
employees[2]["name"]
# Out:
# 'Charlie'

# %% [markdown]
# ## 문제 풀이 2

# %%
employees1 = {"name" : "Alie",
              "department" : "Sales",
              "position" : "Manager",
              "year" : "2023"}

# %%
employees1["position"]
# Out:
# 'Manager'

# %% [markdown]
# ## 문제 풀이 3

# %%
all_employees = [

]

# %%
employees01 = {"name" : "Alice",
               "department" : "Sales",
               "position" : "Manager",
               "year" : "2023"}

# %%
employees02 = {"name" : "Bob",
               "department" : "IT",
               "position" : "Engineer",
               "year" : "2022"}

# %%
employees03 = {"name" : "Charlie",
               "department" : "HR",
               "position" : "Staff",
               "year" : "2023"}

# %%
employees04 = {"name" : "Diana",
               "department" : "Marketing",
               "position" : "Analyst",
               "year" : "2024"}

# %%
# all_employees
employees_duct = [{"name" : "Alice",
               "department" : "Sales",
               "position" : "Manager",
               "year" : "2023"},
               {"name" : "Bob",
               "department" : "IT",
               "position" : "Engineer",
               "year" : "2022"},
               {"name" : "Charlie",
               "department" : "HR",
               "position" : "Staff",
               "year" : "2023"},
               {"name" : "Diana",
               "department" : "Marketing",
               "position" : "Analyst",
               "year" : "2024"}]

# %%
employees_list = [employees01, employees02, employees03, employees04]

# %%
employees_duct[2]
# Out:
# {'name': 'Charlie', 'department': 'HR', 'position': 'Staff', 'year': '2023'}

# %%
employees_duct[1]["position"]
# Out:
# 'Engineer'
